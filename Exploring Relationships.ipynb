# %% [markdown]
# # Importing Libraries

# %%
#Importing Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import scipy
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
# Creating a path to import dataframe

path = r'/Users/shailioza/Documents/CareerFoundry Projects'

# %%
# Importing Dataframe 

df = pd.read_csv(os.path.join(path, 'pollution_clean.csv'))

# %%
# Check the matplotlib version

matplotlib.__version__
# Out:
# '3.7.0'

# %%
df.head(15)
# Out:
#     Unnamed: 0        Date  Year  Month  Day  \
# 0            0  2000-01-01  2000      1    1
# 1            1  2000-01-02  2000      1    2
# 2            2  2000-01-03  2000      1    3
# 3            3  2000-01-04  2000      1    4
# 4            4  2000-01-05  2000      1    5
# 5            5  2000-01-06  2000      1    6
# 6            6  2000-01-07  2000      1    7
# 7            7  2000-01-08  2000      1    8
# 8            8  2000-01-09  2000      1    9
# 9            9  2000-01-10  2000      1   10
# 10          10  2000-01-11  2000      1   11
# 11          11  2000-01-12  2000      1   12
# 12          12  2000-01-13  2000      1   13
# 13          13  2000-01-14  2000      1   14
# 14          14  2000-01-15  2000      1   15
#
#                                     Address    State    County     City  \
# 0   1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 1   1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# ...

# %%
# Columns list

df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Year', 'Month', 'Day', 'Address', 'State',
#        'County', 'City', 'O3 Mean', 'O3 1st Max Value', 'O3 1st Max Hour',
#        'O3 AQI', 'CO Mean', 'CO 1st Max Value', 'CO 1st Max Hour', 'CO AQI',
#        'SO2 Mean', 'SO2 1st Max Value', 'SO2 1st Max Hour', 'SO2 AQI',
#        'NO2 Mean', 'NO2 1st Max Value', 'NO2 1st Max Hour', 'NO2 AQI'],
#       dtype='object')

# %% [markdown]
# # 2. Make subsets of data with columns relevant to the analysis based on questions in previous exercise

# %% [markdown]
# ## Questions to explore:
#
# 1. Where - Which states have the highest pollutants? (include State, O3 AQI, CO AQI, SO2 AQI, NO2 AQI)
#
#
# 2. Why - What are the causes of certain pollutants in the atmosphere? Industrial? Vehicular? Household? (Ozone: Environmental, Carbon Monoxide: Vehicular/Transportation and Household, Sulfur Dioxide: Industrial, Nitrogen Dioxide: Vehicular/Transportation and Induatrial)
#
#
# 3. When - What are the pollution trends across 2 decades? Monitor effects of COVID-19 lockdown, fuel prices, etc. (include year, month, state and all pollutant columns with AQI)
#
#
# 4. How can these pollutants be reduced to improve air quality?
#
#
# 5. What is the threshold of safe air quality? (include categories of AQI after some wrangling)
#
#
# 6. Recommendations for the general public based on AQI.

# %% [markdown]
# #df_all = df[['Date', 'Year', 'Month', 'Day', 'State',
#        'County', 'City', 'O3 Mean', 'O3 1st Max Value', 'O3 1st Max Hour','O3 AQI', 'CO Mean', 'CO 1st Max Value', 'CO 1st Max Hour', 'CO AQI','SO2 Mean', 'SO2 1st Max Value', 'SO2 1st Max Hour', 'SO2 AQI', 'NO2 Mean', 'NO2 1st Max Value', 'NO2 1st Max Hour', 'NO2 AQI']]

# %%
# Drop specific unnecesary columns
columns_to_drop = ['Unnamed: 0', 'Year','Month','Date', 'Day', 'Address', 'State', 'County', 'City']
df.drop(columns_to_drop, axis=1, inplace=True)

# %%
df.head()
# Out:
#     O3 Mean  O3 1st Max Value  O3 1st Max Hour  O3 AQI   CO Mean  \
# 0  0.019765             0.040               10      37  0.878947
# 1  0.015882             0.032               10      30  1.066667
# 2  0.009353             0.016                9      15  1.762500
# 3  0.015882             0.033                9      31  1.829167
# 4  0.007353             0.012                9      11  2.700000
#
#    CO 1st Max Value  CO 1st Max Hour  CO AQI  SO2 Mean  SO2 1st Max Value  \
# 0               2.2               23    25.0  3.000000                9.0
# 1               2.3                0    26.0  1.958333                3.0
# 2               2.5                8    28.0  5.250000               11.0
# 3               3.0               23    34.0  7.083333               16.0
# 4               3.7                2    42.0  8.708333               15.0
#
#    SO2 1st Max Hour  SO2 AQI   NO2 Mean  NO2 1st Max Value  NO2 1st Max Hour  \
# ...

# %% [markdown]
# # 3. Correlation Heatmap

# %%
# Create a correlation matrix using pandas

df.corr()
# Out:
#                     O3 Mean  O3 1st Max Value  O3 1st Max Hour    O3 AQI  \
# O3 Mean            1.000000          0.888518         0.021499  0.793863
# O3 1st Max Value   0.888518          1.000000        -0.064274  0.929857
# O3 1st Max Hour    0.021499         -0.064274         1.000000 -0.049276
# O3 AQI             0.793863          0.929857        -0.049276  1.000000
# CO Mean           -0.273209         -0.151465        -0.007168 -0.084290
# CO 1st Max Value  -0.301805         -0.156892        -0.023997 -0.092787
# CO 1st Max Hour   -0.234551         -0.096716        -0.065372 -0.066807
# CO AQI            -0.303138         -0.155110        -0.023738 -0.090376
# SO2 Mean          -0.086037         -0.016934         0.023030  0.039505
# SO2 1st Max Value -0.043668          0.027267         0.017486  0.067252
# SO2 1st Max Hour  -0.074582         -0.009191        -0.034449  0.006818
# SO2 AQI           -0.046982          0.027907         0.018712  0.070237
# ...

# %%
# Create a correlation heatmap using matplotlib

plt.matshow(df.corr())
plt.show()

# %%
# Add labels, a legend, and change the size of the heatmap

f = plt.figure(figsize=(8, 8)) # figure size 
plt.matshow(df.corr(), fignum=f.number) # type of plot
plt.xticks(range(df.shape[1]), df.columns, fontsize=10, rotation=90) # x axis labels
plt.yticks(range(df.shape[1]), df.columns, fontsize=10) # y axis labels
cb = plt.colorbar() # add a colour legend (called colorbar)
cb.ax.tick_params(labelsize=14) # add font size
plt.title('Correlation Matrix', fontsize=14) # add title
plt.savefig("corr_all.png")  #save

# %% [markdown]
# ## 3B. Create a correlation matrix heatmap (colored) in seaborn

# %%
# Create a subplot with matplotlib
f,ax = plt.subplots(figsize=(20,20))

# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.
corr = sns.heatmap(df.corr(), annot = True, ax = ax) # The `annot` argument allows the plot to 
#place the correlation coefficients onto the heatmap.

# %% [markdown]
# ### Notes: We can see from the heatmap that Mean of each pollutant is strongly correlated with AQI of the same pollutant. There is also some positive correlation between Carbon Monoxide and Nitrogen Dioxide which can be further explored.

# %% [markdown]
# # 4. Scatterplot (or plots) for the variables with the strongest correlations

# %%
# I will make a scatter plot of CO and NO2

sns.lmplot(x = 'CO AQI', y = 'NO2 AQI', data = df)

# %% [markdown]
# ### There does seem to be some correlation but there is so much data in the middle that it is not a definitive linear trend

# %% [markdown]
# # 5. Pair plot of the entire data set

# %%
# Since there are too many data points for pair plots, I will narrow it down to only necessary columns
# Keep only the variables I want to use in the pair plot

sub = df[['O3 AQI', 'NO2 AQI', 'CO AQI', 'SO2 AQI']]

# %%
# Create a pair plot 

g = sns.pairplot(sub)

# %% [markdown]
# ### There seems to be some correlation between CO, O3 and NO2 gases, and not very strong relation with SO2.
# ### There also seems reduced air pollutants during the covid years (2019, 2020 and 2021), however, ozone aqi does not reduce significantly.
#
# #### O3 (Ozone):
# Environmental: Ozone is formed in the atmosphere through complex reactions involving sunlight, nitrogen oxides (NOx), and volatile organic compounds (VOCs) emitted from various sources. It is not directly emitted by specific sectors or activities but forms due to the interaction of pollutants in the presence of sunlight. Ozone levels can be influenced by factors such as weather conditions and long-range transport of pollutants.
#
# #### CO (Carbon Monoxide):
# Vehicular/Transportation: Carbon monoxide is primarily produced by the incomplete combustion of fossil fuels, particularly in vehicles and transportation-related activities. It is released from exhaust emissions of cars, trucks, motorcycles, and other motor vehicles.
#
# Household: Carbon monoxide can also be emitted from sources within households, such as malfunctioning or poorly vented fuel-burning appliances (e.g., gas stoves, furnaces, and fireplaces) or the burning of biomass (e.g., wood and charcoal) indoors without adequate ventilation.
#
# #### SO2 (Sulfur Dioxide):
# Industrial: Sulfur dioxide is primarily emitted during the combustion of fossil fuels, especially those containing high sulfur content, such as coal and oil. It is released by industrial processes such as power generation, manufacturing, and the burning of fossil fuels in industrial facilities.
#
# #### NO2 (Nitrogen Dioxide):
# Vehicular/Transportation: Nitrogen dioxide is produced from the combustion of fossil fuels at high temperatures, primarily in vehicles. It is a prominent component of vehicle exhaust and is released during the combustion of gasoline and diesel in cars, trucks, motorcycles, and other motor vehicles.
#
# Industrial: Nitrogen dioxide can also be emitted from industrial activities such as power generation, manufacturing, and other combustion processes.
#
# ### Therefore, most pollution seems to be due to vehicular, household and environmental factors

# %% [markdown]
# # 6. Categorical Plot

# %%
# Use a histogram to visualize the distribution of the variables. 
# This way, you can determine sensible categories for the ranges. 
# You don't want to end up with too few observations in any one of the categories.
# The argument "kde" add a line that encompasses the distribution
sns.histplot(df['O3 Mean'], bins = 20, kde = True)
# Out:
# <Axes: xlabel='O3 Mean', ylabel='Count'>

# %%
sns.histplot(df['NO2 Mean'], bins = 20, kde = True)
# Out:
# <Axes: xlabel='NO2 Mean', ylabel='Count'>

# %%
sns.histplot(df['CO Mean'], bins = 20, kde = True)
# Out:
# <Axes: xlabel='CO Mean', ylabel='Count'>

# %%
sns.histplot(df['SO2 Mean'], bins = 20, kde = True)
# Out:
# <Axes: xlabel='SO2 Mean', ylabel='Count'>

# %% [markdown]
# ### Creating a categorical variable that splits the 'O3 Mean' column into categories
# ### Also creating categorical variable that categorizes pollutants

# %%
df.loc[df['O3 Mean'] < 0.054, 'O3 AQI Category'] = 'Good'

# %%
df.loc[(df['O3 Mean'] >= 0.055) & (df['O3 Mean'] < 0.071), 'O3 AQI Category'] = 'Moderate'

# %%
df.loc[(df['O3 Mean'] >= 0.071) & (df['O3 Mean'] < 0.086), 'O3 AQI Category'] = 'Unhealthy for Sensitive Groups'

# %%
df.loc[(df['O3 Mean'] >= 0.086) & (df['O3 Mean'] < 0.106), 'O3 AQI Category'] = 'Unhealthy'

# %%
df.loc[(df['O3 Mean'] >= 0.106) & (df['O3 Mean'] < 0.200), 'O3 AQI Category'] = 'Very Unhealthy'

# %%
df.loc[df['O3 Mean'] >= 0.200, 'O3 AQI Category'] = 'Hazardous'

# %%
df['O3 AQI Category'].value_counts(dropna = False)
# Out:
# Good                              593940
# Moderate                           10599
# NaN                                 2136
# Unhealthy for Sensitive Groups       505
# Unhealthy                             39
# Very Unhealthy                         1
# Name: O3 AQI Category, dtype: int64

# %% [markdown]
# #### We can also categorize the AQI using O3 AQI column as follows but I have chosen to use O3 Mean as my reference measure.
# Good (0-50 AQI)
#
#
# Moderate (51-100 AQI)
#
#
# Unhealthy for Sensitive Groups (101-150 AQI)
#
#
# Unhealthy (151-200 AQI)
#
#
# Very Unhealthy (201-300 AQI)
#
#
# Hazardous (>300 AQI)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Year', 'Month', 'Day', 'Address', 'State',
#        'County', 'City', 'O3 Mean', 'O3 1st Max Value', 'O3 1st Max Hour',
#        'O3 AQI', 'CO Mean', 'CO 1st Max Value', 'CO 1st Max Hour', 'CO AQI',
#        'SO2 Mean', 'SO2 1st Max Value', 'SO2 1st Max Hour', 'SO2 AQI',
#        'NO2 Mean', 'NO2 1st Max Value', 'NO2 1st Max Hour', 'NO2 AQI',
#        'O3 AQI Category'],
#       dtype='object')

# %% [markdown]
# ### NO2 categorizing

# %%
df.loc[df['NO2 Mean'] < 53, 'NO2 AQI Category'] = 'Good'

# %%
df.loc[(df['NO2 Mean'] >= 54) & (df['NO2 Mean'] < 100), 'NO2 AQI Category'] = 'Moderate'

# %%
df.loc[(df['NO2 Mean'] >= 101) & (df['NO2 Mean'] < 360), 'NO2 AQI Category'] = 'Unhealthy for Sensitive Groups'

# %%
df.loc[(df['NO2 Mean'] >= 361) & (df['NO2 Mean'] < 649), 'NO2 AQI Category'] = 'Unhealthy'

# %%
df.loc[(df['NO2 Mean'] >= 650) & (df['NO2 Mean'] < 1249), 'NO2 AQI Category'] = 'Very Unhealthy'

# %%
df.loc[df['NO2 Mean'] >= 1250, 'NO2 AQI Category'] = 'Hazardous'

# %%
df['NO2 AQI Category'].value_counts(dropna = False)
# Out:
# Good                              606143
# Moderate                             942
# NaN                                  126
# Unhealthy for Sensitive Groups         9
# Name: NO2 AQI Category, dtype: int64

# %% [markdown]
# ### CO Categorizing

# %%
df.loc[df['CO Mean'] < 4.4, 'CO AQI Category'] = 'Good'

# %%
df.loc[(df['CO Mean'] >= 4.5) & (df['CO Mean'] < 9.4), 'CO AQI Category'] = 'Moderate'

# %%
df.loc[(df['CO Mean'] >= 9.5) & (df['CO Mean'] < 12.4), 'CO AQI Category'] = 'Unhealthy for Sensitive Groups'

# %%
df.loc[(df['CO Mean'] >= 12.5) & (df['CO Mean'] < 15.4), 'CO AQI Category'] = 'Unhealthy'

# %%
df.loc[(df['CO Mean'] >= 15.5) & (df['CO Mean'] < 30.4), 'CO AQI Category'] = 'Very Unhealthy'

# %%
df.loc[df['CO Mean'] >= 30.5, 'CO AQI Category'] = 'Hazardous'

# %%
df['CO AQI Category'].value_counts(dropna = False)
# Out:
# Good        607197
# Moderate        21
# NaN              2
# Name: CO AQI Category, dtype: int64

# %% [markdown]
# ### SO2 Categorizing

# %%
df.loc[df['SO2 Mean'] < 35, 'SO2 AQI Category'] = 'Good'

# %%
df.loc[(df['SO2 Mean'] >= 36) & (df['SO2 Mean'] < 75), 'SO2 AQI Category'] = 'Moderate'

# %%
df.loc[(df['SO2 Mean'] >= 76) & (df['SO2 Mean'] < 185), 'SO2 AQI Category'] = 'Unhealthy for Sensitive Groups'

# %%
df.loc[(df['SO2 Mean'] >= 186) & (df['SO2 Mean'] < 304), 'SO2 AQI Category'] = 'Unhealthy'

# %%
df.loc[(df['SO2 Mean'] >= 305) & (df['SO2 Mean'] < 604), 'SO2 AQI Category'] = 'Very Unhealthy'

# %%
df.loc[df['SO2 Mean'] >= 605, 'SO2 AQI Category'] = 'Hazardous'

# %%
df['SO2 AQI Category'].value_counts(dropna = False)
# Out:
# Good                              607168
# Moderate                              40
# NaN                                   10
# Unhealthy for Sensitive Groups         1
# Very Unhealthy                         1
# Name: SO2 AQI Category, dtype: int64

# %%
df.head()
# Out:
#    Unnamed: 0        Date  Year  Month  Day  \
# 0           0  2000-01-01  2000      1    1
# 1           1  2000-01-02  2000      1    2
# 2           2  2000-01-03  2000      1    3
# 3           3  2000-01-04  2000      1    4
# 4           4  2000-01-05  2000      1    5
#
#                                    Address    State    County     City  \
# 0  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 1  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 2  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 3  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 4  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
#
#     O3 Mean  ...  SO2 1st Max Hour  SO2 AQI   NO2 Mean  NO2 1st Max Value  \
# 0  0.019765  ...                21     13.0  19.041667               49.0
# 1  0.015882  ...                22      4.0  22.958333               36.0
# ...

# %%
sub_2 = df[['NO2 Mean', 'O3 Mean', 'O3 AQI Category']]

# %%
sub_2.head()
# Out:
#     NO2 Mean   O3 Mean O3 AQI Category
# 0  19.041667  0.019765            Good
# 1  22.958333  0.015882            Good
# 2  38.125000  0.009353            Good
# 3  40.260870  0.015882            Good
# 4  48.450000  0.007353            Good

# %%
sub_sample = sub_2.head(1000)

# %%
# Create a categorical plot in seaborn using the categories created above

sns.set(style="ticks")
g = sns.catplot(x="NO2 Mean", y="O3 Mean", hue="O3 AQI Category", data=sub_sample)

# %%
# Create a categorical plot in seaborn using the categories created above

sns.set(style="ticks")
g = sns.catplot(x="NO2 Mean", y="O3 Mean", hue="O3 AQI Category", data=sub_2)
# Out:
# /Users/shailioza/anaconda3/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # 7. Revisit the questions you generated in the previous task and write answers to those you can based on the exploration you’ve conducted so far. Add any new questions that may have arisen based on the early findings in your visual exploration.

# %% [markdown]
# 1. Where - Which states have the highest pollutants? (include State, O3 AQI, CO AQI, SO2 AQI, NO2 AQI)
# This question can be answered after geo-spatial analysis.
#
# 2. Why - What are the causes of certain pollutants in the atmosphere? Industrial? Vehicular? Household? (Ozone: Environmental, Carbon Monoxide: Vehicular/Transportation and Household, Sulfur Dioxide: Industrial, Nitrogen Dioxide: Vehicular/Transportation and Induatrial)
# This question can be answered after time-series analysis.
#
#
# 3. When - What are the pollution trends across 2 decades? Monitor effects of COVID-19 lockdown, fuel prices, etc. (include year, month, state and all pollutant columns with AQI)
# This question can be answered after time-series analysis.
#
# 4. How can these pollutants be reduced to improve air quality?
# Environmental pollutants like Ozone can be reduced by planting more trees regularly.
#
# Considering the Vehicular pollutants, people should be encouraged to use more public transport or carpooling for their daily commute. They must get their vehicle checked regularly for optimal functioning and lower gaseous waste.
#
# Household pollutants can be lowered by proper ventilation while burning.
#
# Industries must be located in the outskirts of cities and towns, surrounded by forests in order to reduce the effects of industrial gases contributing to the Green House Effect.
#
# 5. What is the threshold of safe air quality? (include categories of AQI after some wrangling)
# Good (0-50 AQI)
# Moderate (51-100 AQI)
# Unhealthy for Sensitive Groups (101-150 AQI)
# Unhealthy (151-200 AQI)
# Very Unhealthy (201-300 AQI)
# Hazardous (>300 AQI)
#
# 6. Recommendations for the general public based on AQI.
# Daily AQI data can be used to forecast weather in particular areas. People can refer to this forecast and plan their trips or days accordingly. A prediction for the next day or several days allows people to plan their activities so that they can reduce or avoid exposure to air pollution.
#
# Using electric cars can help reduce vehicular pollutants. Even using public trnasport and carpooling can add to the same cause.
#
# Individuals with certain health conditions must avoid outdoor exposure when the AQI is Unhealthy or worse.
#
# Coaches avoid training their athletes in the open during bad AQI days as it reduced performance and could induce Asthma and breathing problems in sensitive individuals.
#
# 7. How do these pollutants affect general population?
# Ozone - People with lung disease, children, older adults, people who are active
# outdoors (including outdoor workers), people with certain genetic variants,
# and people with diets limited in certain nutrients are the groups most at
# risk
#
# Carbon Monoxide - People with heart disease is the group most at risk
#
# Nitrogen Dioxide - People with asthma, children, and older adults are the groups most at risk
#
# Sulfur Dioxide - People with asthma, children, and older adults are the groups most at risk
#
#
# 8. NEW QUESTIONS
#
#
# What will be the future AQI levels based on historical data.
#
#
# Does any state require immediate intervention to reduce pollutants?

# %% [markdown]
# # 8. Define any hypothesis that you can at this point. You’ll be testing these later on.

# %% [markdown]
# ##### 1. Hypothesis: Air pollution levels (measured by O3, CO, SO2, and NO2) vary significantly between different states/counties/cities.
#
#
# ##### 2. Hypothesis: There is a relationship between air pollutant concentrations and specific days of the months or months of a year.
#    - Explore whether air pollution levels exhibit any patterns or trends based on the day of the month (e.g., end of month) or the month of the year. This can help identify if certain days or seasons are associated with higher pollution levels.
#
#
#
# ##### 3. Hypothesis: There is a correlation between different air pollutants (O3, CO, SO2, NO2) and their respective Air Quality Index (AQI) values.
#    - Analyze the relationships between different air pollutants and their corresponding AQI values. This can help determine if certain pollutants have a stronger impact on air quality or if there are consistent patterns across the pollutants.
#
#
#
# ##### 4. Hypothesis: The levels of specific air pollutants have changed over time.
#    - Examine whether there have been any trends or changes in air pollutant concentrations over the years. This could involve analyzing yearly, monthly, or seasonal variations in the data.
#
#
#
# ##### 5. Hypothesis: There is a correlation between air pollutant concentrations and health impact (measured by AQI).
#    - Investigate the relationship between air pollutant concentrations (such as O3, CO, SO2, NO2) and their corresponding AQI values. This can help understand the potential health risks associated with different pollutant levels. This would require data on hospital admissions related to respiratory symptoms or prevalence of respiratory diseases in a population. This would also require data on population density, socioeconomic factors, or weather conditions, that may also influence respiratory health outcomes. I will consider this hypothesis if I am able to find remaining data required.

# %%
#Export the dataset
df.to_csv(r'/Users/shailioza/Documents/CareerFoundry Projects/pollution_wrangled.csv')
